# %% [markdown]
# <center> <h1>Seaborn BarPlot Part 2</h1></center>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df= sns.load_dataset("tips")                                                 # Load dataset
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
"""
sns.barplot(
    x=None,
    y=None,
    seed=None,
    ax=None,
    **kwargs,
)
""";

# %%
sns.barplot(x='day', y='total_bill', data=df, hue='sex')                   # Simple bar plot
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
kwargs= {'alpha':0.6, 'linestyle':':', 'linewidth':6, 'edgecolor':'k'}           # pass keyword arguments to plot as dict
sns.barplot(x='day', y='total_bill', data=df, hue='sex', **kwargs)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Pass Keyword arguments as dict

# %%
sns.set()
kwargs= {'alpha':0.6, 'linestyle':':', 'linewidth':6, 'edgecolor':'k'}           
sns.barplot(x='day', y='total_bill', data=df, **kwargs)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Pass Keyword arguments as parameter

# %%
sns.barplot(x='day', y='total_bill', data=df, linestyle='-.', edgecolor='k', alpha=0.7, linewidth=3)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Use (ax)axis parameter

# %%
ax= sns.barplot(x='day',y='total_bill',data=df,alpha=0.8, linestyle='-.', linewidth=3, edgecolor='g')

ax.set(title='Barplot of Tips DataFrame',
      xlabel='Days',
      ylabel='Total Bill')
# Out:
# [Text(0.5, 1.0, 'Barplot of Tips DataFrame'),
#  Text(0.5, 0, 'Days'),
#  Text(0, 0.5, 'Total Bill')]

# %% [markdown]
# # Show Bar Plot data Professionally

# %%
plt.figure(figsize=(16,9))
sns.barplot(x='day', y='total_bill', data=df, alpha=0.9, linestyle=':', linewidth=7, edgecolor='g')
plt.title('Effective Bar Plot', fontsize=30)
plt.xlabel('Days' , fontsize=20)
plt.ylabel('Total Bill', fontsize=20)
plt.savefig('Tut62.png')
plt.show()
