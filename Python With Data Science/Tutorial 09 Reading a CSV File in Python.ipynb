# %%
import pandas as pd

# %%
df1 = pd.read_csv('Tut9Data.csv')

# %%
df1
# Out:
#           SYMBOL SERIES         DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 0      20MICRONS     EQ   14-Jan-2021       39.00       39.00       40.80
# 1     21STCENMGM     EQ   14-Jan-2021       10.60       10.60       10.80
# 2     3IINFOTECH     EQ   14-Jan-2021        8.55        8.15        8.15
# 3        3MINDIA     EQ   14-Jan-2021    21267.55    21489.00    21489.00
# 4         3PLAND     EQ   14-Jan-2021       10.20       10.20       10.65
# ...          ...    ...           ...         ...         ...         ...
# 2009   ZODJRDMKJ     EQ   14-Jan-2021       29.75       28.85       31.20
# 2010        ZOTA     EQ   14-Jan-2021      162.35      164.85      168.00
# 2011       ZUARI     EQ   14-Jan-2021      105.10      105.90      107.00
# 2012   ZUARIGLOB     BE   14-Jan-2021      112.70      109.30      112.00
# 2013   ZYDUSWELL     EQ   14-Jan-2021     2023.75     2020.40     2037.60
#
#       LOW_PRICE LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  \
# ...

# %%
print(df1['SYMBOL'].dtype)
# Out:
# object

# %%
print(df1['PREV_CLOSE'].dtype)
# Out:
# float64

# %%
print(df1['SERIES'].dtype)
# Out:
# object

# %%
print(df1['SERIES'].astype('category'))
# Out:
# 0        EQ
# 1        EQ
# 2        EQ
# 3        EQ
# 4        EQ
#        ...
# 2009     EQ
# 2010     EQ
# 2011     EQ
# 2012     BE
# 2013     EQ
# Name: SERIES, Length: 2014, dtype: category
# Categories (75, object): [' BE', ' BZ', ' E1', ' EQ', ..., ' ZD', ' ZG', ' ZH', ' ZK']
